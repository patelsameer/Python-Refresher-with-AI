# %% [markdown]
# <a href="https://colab.research.google.com/github/patelsameer/Python-Refresher-with-AI/blob/main/My_first_python_program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")

'''

this is multi line comment for long description

'''

print("multi line comment")
# Out:
# hello world
# multi line comment

# %% [markdown]
# use input to see how it work in python

# %%
name= input("enter your name")
print("hello  " +name + "  welcome to python programming !!!")
# Out:
# enter your namesameer
# hello  sameer   welcome to python programming !!!
