# %% [markdown]
# <a href="https://colab.research.google.com/github/patelsameer/Python-Refresher-with-AI/blob/main/Comapring_Operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Taking two numbers as input from the user

a = int(input("Enter first number: "))

b = int(input("Enter second number: "))

# Applying comparison operators and displaying results

print(f"{a} > {b} :", a > b)

print(f"{a} < {b} :", a < b)

print(f"{a} >= {b} :", a >= b)

print(f"{a} <= {b} :", a <= b)

print(f"{a}  {b} :", a , b)

print(f"{a} != {b} :", a != b)
# Out:
# Enter first number: 88
# Enter second number: 88
# 88 > 88 : False
# 88 < 88 : False
# 88 >= 88 : True
# 88 <= 88 : True
# 88  88 : 88 88
# 88 != 88 : False
